# %% [markdown]
# # Geomechanical Injection Scenario Toolkit (GIST)
#
# #Disclaimer
# GIST aims to give the _gist_ of a wide range of potential scenarios and aid collective decision making when responding to seismicity.
#
# The results of GIST are entirely dependent upon the inputs provided, which may be incomplete or inaccurate.
#
# There are other potentially plausible inducement scenarios that are not considered, including fluid migration into the basement,
# out-of-zone poroelastic stressing, or hydraulic fracturing.
#
# None of the individual models produced by GIST accurately represent what happens in the subsurface and cannot be credibly used
# to accurately assign liability or responsibility for seismicity.
#
# "All models are wrong, but some are useful" - George Box, 1976
#
# ## Prerequisites
#
# Assumes InjectionSQLScheduled completed successfully and injection data are sampled uniformly in time

# %% [markdown]
# ##Install Dependencies
# - geopandas
# - gistMC.py
# - eqSQL.py
# - gistPlots.py
# - numpy
# - scipy
# - pandas

# %%
# %restart_python

# %%
# %run "/Workspace/_utils/Utility_Functions"

# %%
# !pip install geopandas
# !pip install geodatasets
# !pip install contextily
#! pip install folium matplotlib mapclassify contextily
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in /databricks/python3/lib/python3.12/site-packages (from geopandas) (2.1.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.16.0)
# Downloading geopandas-1.1.2-py3-none-any.whl (341 kB)
# Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl (32.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 99.2 MB/s eta 0:00:00
# Downloading pyproj-3.7.2-cp312-cp312-manylinux_2_28_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 121.2 MB/s eta 0:00:00
# Downloading shapely-2.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.3 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.1.2 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Collecting geodatasets
#   Downloading geodatasets-2026.1.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting pooch (from geodatasets)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /databricks/python3/lib/python3.12/site-packages (from pooch->geodatasets) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from pooch->geodatasets) (24.2)
# Requirement already satisfied: requests>=2.19.0 in /databricks/python3/lib/python3.12/site-packages (from pooch->geodatasets) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->geodatasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->geodatasets) (2025.1.31)
# Downloading geodatasets-2026.1.0-py3-none-any.whl (22 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Installing collected packages: pooch, geodatasets
# Successfully installed geodatasets-2026.1.0 pooch-1.8.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Collecting contextily
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting geopy (from contextily)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.12/site-packages (from contextily) (3.10.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /databricks/python3/lib/python3.12/site-packages (from contextily) (11.1.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.5.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.12/site-packages (from contextily) (1.4.2)
# Collecting xyzservices (from contextily)
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /databricks/python3/lib/python3.12/site-packages (from mercantile->contextily) (8.1.7)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /databricks/python3/lib/python3.12/site-packages (from rasterio->contextily) (24.3.0)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from rasterio->contextily) (2025.1.31)
# Collecting cligj>=0.5 (from rasterio->contextily)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests->contextily) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests->contextily) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rasterio-1.5.0-cp312-cp312-manylinux_2_28_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 91.5 MB/s eta 0:00:00
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: xyzservices, mercantile, geographiclib, cligj, affine, rasterio, geopy, contextily
# Successfully installed affine-2.4.0 cligj-0.7.2 contextily-1.7.0 geographiclib-2.1 geopy-2.4.1 mercantile-1.2.1 rasterio-1.5.0 xyzservices-2025.11.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ##Paths

# %%
# Paths
homePath='/Workspace/Users/bill.curry@exxonmobil.com/'
# Injection data path 
injPath=homePath+'injection/WeeklyRun/ScheduledOutput/'
# GIST library path
gistPath=homePath+'GIST/'

# %% [markdown]
# ##Libraries
#
# - numpy
# - scipy
# - pandas
# - matplotlib
# - geopandas
# - pyspark

# %%
import sys
sys.path.append(gistPath+'lib')

# %%
#Databricks-specific
#import dataBricksConfig as db
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("eqSQL").getOrCreate()

# %%
import numpy as np
import pandas as pd
import os
import gistMC as gi
import eqSQL as es
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
#import contextily as cx

# %%
import gistPlots as gp

# %% [markdown]
# #1. Select Event

# %% [markdown]
# ##1.1. Parameters: TexNet event ID + forecast duration

# %%
eventID='tx2025zqwqjm'
forecastYears=1.

# %% [markdown]
# ##1.2. Results: Create directories, fetch EQ

# %%
runPath=gistPath+'/runs/'+eventID+'/'
os.makedirs(runPath, exist_ok=True)

# %%
eqs=es.eqSQL()
EQDF=eqs.getEarthquake(eventID)
EQDF=EQDF.rename(columns={'LatitudeErrorKm':'LatitudeError','LongitudeErrorKm':'LongitudeError','EventId':'EventID'})
# We could make use of the Rake
EQDF.info()
eq=EQDF.loc[0]
print(eq)
# Out:
# getEarthquake:     SeismicEventId  ... B3RecordDeletedUTCDateTime
# 0         2889501  ...                        NaT
# 1         2889531  ...                        NaT
#
# [2 rows x 32 columns] 2
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SeismicEventId              2 non-null      int64
#  1   DataSource                  2 non-null      object
#  2   DataSourceUrl               1 non-null      object
#  3   EventID                     2 non-null      object
#  4   EventTimeUtc                2 non-null      object
#  5   EventTimeInLocalTimeZone    2 non-null      object
#  6   EventTimeZone               2 non-null      object
#  7   EventType                   2 non-null      object
#  8   DepthKm                     2 non-null      float64
#  9   DepthErrorKm                1 non-null      float64
#  10  Magnitude                   2 non-null      float64
#  11  MagnitudeError              1 non-null      float64
#  12  MagnitudeType               2 non-null      object
#  13  Location                    2 non-null      object
#  14  Status                      2 non-null      object
#  15  Latitude                    2 non-null      float64
#  16  LatitudeError               2 non-null      float64
#  17  Longitude                   2 non-null      float64
#  18  LongitudeError              2 non-null      float64
#  19  UpdatedDateUtc              2 non-null      object
#  20  StationCount                2 non-null      int64
#  21  RMS                         2 non-null      float64
#  22  RMS_p                       0 non-null      object
#  23  RMS_s                       0 non-null      object
#  24  FocalMechanismAzimuthalGap  1 non-null      float64
#  25  County                      2 non-null      object
#  26  State                       2 non-null      object
#  27  DuplicateSetId              2 non-null      int32
#  28  RankWithinDuplicateSet      2 non-null      int32
#  29  B3RecordAddedUTCDateTime    2 non-null      datetime64[ns]
#  30  B3RecordUpdatedUTCDateTime  2 non-null      datetime64[ns]
#  31  B3RecordDeletedUTCDateTime  0 non-null      datetime64[ns]
#  32  Origin Date                 2 non-null      object
#  33  Origin Time                 2 non-null      object
#  34  geometry                    2 non-null      geometry
# dtypes: datetime64[ns](3), float64(10), geometry(1), int32(2), int64(2), object(17)
# memory usage: 676.0+ bytes
# SeismicEventId                                     2889501
# DataSource                       TexNet Earthquake Catalog
# DataSourceUrl                                         None
# EventID                                       tx2025zqwqjm
# EventTimeUtc                          2025-12-30T07:03:26Z
# EventTimeInLocalTimeZone              2025-12-30T01:03:26Z
# EventTimeZone                                          CST
# EventType                                       Earthquake
# DepthKm                                           8.837891
# DepthErrorKm                                      1.028479
# Magnitude                                         2.518896
# MagnitudeError                                         NaN
# MagnitudeType                                   ml(texnet)
# Location                                     Western Texas
# Status                                               final
# Latitude                                         31.946411
# LatitudeError                                     0.229288
# Longitude                                       -101.46223
# LongitudeError                                    0.220017
# UpdatedDateUtc                        2025-12-30T08:36:09Z
# StationCount                                            30
# RMS                                               0.081086
# RMS_p                                                 None
# RMS_s                                                 None
# FocalMechanismAzimuthalGap                             NaN
# County                                      Glasscock (TX)
# State                                                Texas
# DuplicateSetId                                       18407
# RankWithinDuplicateSet                                   1
# B3RecordAddedUTCDateTime               2025-12-30 10:57:47
# B3RecordUpdatedUTCDateTime             2026-01-07 10:46:47
# B3RecordDeletedUTCDateTime                             NaT
# Origin Date                                     2025-12-30
# Origin Time                                       07:03:26
# geometry                      POINT (-101.46223 31.946411)
# Name: 0, dtype: object

# %%
#EQDF['Strike']=80.
#EQDF['Dip']=55.
#EQDF['Rake']=-85.
#EQDF['Latitude']=31.3329178
#EQDF['Longitude']=-101.905203
#EQDF['Origin Time']=pd.to_datetime('2025-05-02 10:33:24')
#EQDF['Origin Date']=pd.to_datetime('2025-05-02')
#EQDF['EventID']='OwensWell'

# %%
EQDF.to_csv(runPath+'EQ.csv')

# %%
# Should I pickle or just re-run this?
